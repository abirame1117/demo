# %% [markdown]
# <a href="https://colab.research.google.com/github/abirame1117/demo/blob/main/dynamic_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get remove -y chromium-browser chromium-chromedriver
# !rm -rf /opt/google/chrome


# !wget -q -O google-chrome-stable_current_amd64.deb https://d1.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -fy install

# !pip install selenium
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'chromium-browser' is not installed, so not removed
# Package 'chromium-chromedriver' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# dpkg-deb: error: 'google-chrome-stable_current_amd64.deb' is not a Debian format archive
# dpkg: error processing archive google-chrome-stable_current_amd64.deb (--install):
#  dpkg-deb --control subprocess returned error exit status 2
# Errors were encountered while processing:
#  google-chrome-stable_current_amd64.deb
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# ...

# %%
# Step 1: Remove the broken default installations
# !apt-get remove -y chromium-browser chromium-chromedriver
# !rm -rf /opt/google/chrome

# Step 2: Download and install the official Google Chrome Stable
# !wget -q -O google-chrome-stable_current_amd64.deb https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -fy install

# Step 3: Install Selenium
# !pip install selenium
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'chromium-browser' is not installed, so not removed
# Package 'chromium-chromedriver' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (149.0.7827.102-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libatk-bridge2.0-0 (>= 2.5.3); however:
#   Package libatk-bridge2.0-0 is not installed.
#  google-chrome-stable depends on libatk1.0-0 (>= 2.11.90); however:
#   Package libatk1.0-0 is not installed.
#  google-chrome-stable depends on libatspi2.0-0 (>= 2.9.90); however:
#   Package libatspi2.0-0 is not installed.
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

print("setting up the invisible browser.............")

options = webdriver.ChromeOptions()
options.add_argument('--headless=new')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options = options)
print("opening the website...")
driver.get("https://quotes.torscape.com/js/")

print("Waiting 3 secs for java script to load the data....")
time.sleep(3)

print("extracting quotes..\n")
print('-' * 30)

quotes = driver.find_elements(By.CLASS_NAME, "text")

for quote in quotes:
      print(quote.text)

      print("-" * 30)

driver.quit()
print("Scraping complete!")
# Out:
# setting up the invisible browser.............
# opening the website...
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_6139/562845072.py in <cell line: 0>()
#      12 driver = webdriver.Chrome(options = options)
#      13 print("opening the website...")
# ---> 14 driver.get("https://quotes.torscape.com/js/")
#      15
#      16 print("Waiting 3 secs for java script to load the data....")
#
# /usr/local/lib/python3.12/dist-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     486             `driver.get("https://example.com")`
#     487         """
# --> 488         self.execute(Command.GET, {"url": url})
#     489
#     490     @property
#
# /usr/local/lib/python3.12/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     466
#     467         if response:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

print("Setting up the invisible browser...")

options = webdriver.ChromeOptions()
options.add_argument('--headless=new')           # Use the modern headless mode
options.add_argument('--no-sandbox')             # Bypass OS security model
options.add_argument('--disable-dev-shm-usage')  # Prevent memory crashes

# Step 1: Initialize the browser (Selenium handles the driver automatically now!)
driver = webdriver.Chrome(options=options)

# Step 2: Navigate to the dynamic website
print("Opening the website...")
driver.get("https://quotes.toscrape.com/js/")

# Step 3: Wait for the JavaScript to "build" the page
print("Waiting 3 seconds for JavaScript to load the data...")
time.sleep(3)

# Step 4: Locate the data we want to scrape
print("Extracting quotes...\n")
print("-" * 30)
quotes = driver.find_elements(By.CLASS_NAME, "text")

# Step 5: Clean and display the data
for quote in quotes:
    print(quote.text)

print("-" * 30)

    # Step 6: Close the browser to free up memory
driver.quit()
print("Scraping complete!")
# Out:
# Setting up the invisible browser...
# Opening the website...
# Waiting 3 seconds for JavaScript to load the data...
# Extracting quotes...
#
# ------------------------------
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

print("Setting up the invisible browser...")

options = webdriver.ChromeOptions()
options.add_argument('--headless=new')           # Use the modern headless mode
options.add_argument('--no-sandbox')             # Bypass OS security model
options.add_argument('--disable-dev-shm-usage')  # Prevent memory crashes

# Step 1: Initialize the browser (Selenium handles the driver automatically now!)
driver = webdriver.Chrome(options=options)

# Step 2: Navigate to the dynamic website
print("Opening the website...")
driver.get("https://quotes.toscrape.com/js/")

# Step 3: Wait for the JavaScript to "build" the page
print("Waiting 3 seconds for JavaScript to load the data...")
time.sleep(3)

# Step 4: Locate the data we want to scrape
print("Extracting data...\n")
print("-" * 30)
quotes = driver.find_elements(By.CSS_SELECTOR, "div")

# Step 5: Clean and display the data
for quote in quotes:
    print(quote.text)

    print("-" * 30)

    # Step 6: Close the browser to free up memory
    driver.quit()
    print("Scraping complete!")
# Out:
# Setting up the invisible browser...
# Opening the website...
# Waiting 3 seconds for JavaScript to load the data...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError("HTTPConnection(host='localhost', port=54623): Failed to establish a new connection: [Errno 111] Connection refused")': /session/85f5d98b3341b3dc76dead21e7f22e78/element/f.812DEE612D32534A7E1FC65C9E112CD4.d.956782BA4409F4D3095129B7E5DDD33F.e.5/text
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError("HTTPConnection(host='localhost', port=54623): Failed to establish a new connection: [Errno 111] Connection refused")': /session/85f5d98b3341b3dc76dead21e7f22e78/element/f.812DEE612D32534A7E1FC65C9E112CD4.d.956782BA4409F4D3095129B7E5DDD33F.e.5/text
# ...
